# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# #Import All the multiple choice questions with the correct answer and difficulty

# %%
df = pd.read_csv("/content/drive/MyDrive/CSCE306/MultipleChoiceFinal.csv")
df
# Out:
#                                              Question  \
# 0   What symbol is used to denote a single-line co...
# 1      How do you declare an integer variable in C++?
# 2    What is the keyword used to end a C++ statement?
# 3   What C++ construct is used for making decision...
# 4                 How do you perform addition in C++?
# ..                                                ...
# 84  Which of the following is not a valid storage ...
# 85  What is the purpose of the volatile keyword in...
# 86  What is the purpose of the mutable keyword in ...
# 87  Which standard library header file should be i...
# 88  What is the purpose of the inline keyword in C++?
#
#                                                Answer  Difficulty
# 0                                                  //           1
# 1                                                 int           1
# 2                                                   ;           1
# ...

# %%
df = df.rename(columns={'Answer ': 'Answer'})

# %% [markdown]
# #Import a list of possible multiple choice answers.
# Includes answers generated by all the groups, and answers generated by chat gpt

# %%
df1 = pd.read_csv('/content/drive/MyDrive/CSCE306/AnswersList.csv')
df1
# Out:
#     Answers  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       int         NaN         NaN         NaN         NaN         NaN
# 1     float         NaN         NaN         NaN         NaN         NaN
# 2      char         NaN         NaN         NaN         NaN         NaN
# 3      bool         NaN         NaN         NaN         NaN         NaN
# 4    double         NaN         NaN         NaN         NaN         NaN
# ..      ...         ...         ...         ...         ...         ...
# 210      -=         NaN         NaN         NaN         NaN         NaN
# 211      *=         NaN         NaN         NaN         NaN         NaN
# 212      /=         NaN         NaN         NaN         NaN         NaN
# 213      %=         NaN         NaN         NaN         NaN         NaN
# 214     <<=         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 6  Unnamed: 7
# 0           NaN         NaN
# 1           NaN         NaN
# ...

# %% [markdown]
# #Function for generating 3 new columns representing the three incorrect answers.
# The function makes sure that the incorrect answers and the correct answer are all different

# %%
# Function to generate unique incorrect answers
def generate_incorrect_answers(correct_answer, answer_column):
    incorrect_answers = []
    while len(incorrect_answers) < 3:
        incorrect_answer = correct_answer
        correct_length = len(correct_answer)

        if correct_length <= 3:
            while len(incorrect_answer) > 3 or incorrect_answer == correct_answer or incorrect_answer in incorrect_answers:
                incorrect_answer = np.random.choice(answer_column)
        elif 4 <= correct_length <= 8:
            while not (4 <= len(incorrect_answer) <= 8) or incorrect_answer == correct_answer or incorrect_answer in incorrect_answers:
                incorrect_answer = np.random.choice(answer_column)
        else:
            while len(incorrect_answer) <= 8 or incorrect_answer == correct_answer or incorrect_answer in incorrect_answers:
                incorrect_answer = np.random.choice(answer_column)
        incorrect_answers.append(incorrect_answer)

    return incorrect_answers


# Generate incorrect answers for each row
df['incorrect_answers'] = df.apply(lambda row: generate_incorrect_answers(row['Answer'], df['Answer']), axis=1)
df[['incorrect_answer_1', 'incorrect_answer_2', 'incorrect_answer_3']] = pd.DataFrame(df['incorrect_answers'].tolist(), index=df.index)
df.drop(columns=['incorrect_answers'], inplace=True)

df
# Out:
#                                              Question  \
# 0   What symbol is used to denote a single-line co...
# 1      How do you declare an integer variable in C++?
# 2    What is the keyword used to end a C++ statement?
# 3   What C++ construct is used for making decision...
# 4                 How do you perform addition in C++?
# ..                                                ...
# 84  Which of the following is not a valid storage ...
# 85  What is the purpose of the volatile keyword in...
# 86  What is the purpose of the mutable keyword in ...
# 87  Which standard library header file should be i...
# 88  What is the purpose of the inline keyword in C++?
#
#                                                Answer  Difficulty  \
# 0                                                  //           1
# 1                                                 int           1
# 2                                                   ;           1
# ...

# %% [markdown]
# #Saving the dataframe as a JSON file

# %%
# Define the folder path
folder_path = '/content/drive/MyDrive/CSCE306'

# Convert DataFrame to JSON and save to a file in the specified folder
df.to_json(folder_path + 'question_data.json', orient='records')
